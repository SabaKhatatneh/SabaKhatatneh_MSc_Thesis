# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# read the file of disease-concept ids 
dz_con = pd.read_csv('C:/Users/Saba/Desktop/Tutored research project/DrugRepurposing/data/results/ancestors_offsprings.csv', sep=',', header=0, index_col=0)
dz_con= dz_con[['dz_id', 'concept', 'type']]
dz_con= dz_con.reset_index(drop=True)
dz_con
# Out:
#         dz_id   concept       type
# 0      dz:328  C0013264       self
# 1      dz:328  C0026848   ancestor
# 2      dz:328  C0026850   ancestor
# 3      dz:328  C0012634   ancestor
# 4      dz:328  C0026857   ancestor
# ...       ...       ...        ...
# 17564  dz:655  C0861352  offspring
# 17565  dz:655  C0154092  offspring
# 17566  dz:655  C0851140  offspring
# 17567  dz:655  C0154069  offspring
# 17568  dz:655  C0347095  offspring
#
# [17569 rows x 3 columns]

# %%
#Indication matrix (broad id of drugs vs concept ids of diseases)
brd_conc = pd.read_csv('C:/Users/Saba/Desktop/Tutored research project/DrugRepurposing/data/results/brd_conc.csv', sep=',', header=0, index_col=0)
brd_conc
# Out:
#                C0000810  C0000814  C0001126  C0001127  C0001144  C0001206  \
# BRD-ID
# BRD-A00100033         0         0         0         0         0         0
# BRD-A00546892         0         0         0         0         0         0
# BRD-A00758722         0         0         0         0         0         0
# BRD-A00827783         0         0         0         0         0         0
# BRD-A00993607         0         0         0         0         0         0
# ...                 ...       ...       ...       ...       ...       ...
# BRD-K99984802         0         0         0         0         0         0
# BRD-M47793593         0         0         0         0         0         0
# BRD-M98649031         0         0         0         0         0         0
# BRD-U88459701         0         0         0         0         0         0
# BRD-U94846492         0         0         0         0         0         0
#
#                C0001207  C0001261  C0001263  C0001264  ...  C3897537  \
# ...

# %%
# open the correlation matrix (broad id of drugs vs disease ids of diseases)
similarity = pd.read_csv('C:/Users/Saba/Desktop/Tutored research project/DrugRepurposing/data/results/brd_dz_corr.csv', sep=',', header=0, index_col=0)
similarity
# Out:
#                 dz-1000   dz-1001   dz-1002   dz-1003   dz-1004   dz-1005  \
# BRD-K06674495  0.066670  0.118966  0.125683  0.057989  0.122721  0.064734
# BRD-K13005598 -0.013880  0.035840  0.013460 -0.027457  0.019176 -0.035669
# BRD-K53414658 -0.025052 -0.031393 -0.073677 -0.064345  0.057462 -0.057956
# BRD-K09485525  0.067112  0.057495 -0.071661 -0.087242 -0.055037 -0.099037
# BRD-K02950022  0.016955  0.021994  0.029253 -0.051965 -0.010874 -0.026066
# ...                 ...       ...       ...       ...       ...       ...
# BRD-K06234293 -0.029219 -0.044929 -0.105232 -0.131461 -0.049543 -0.053180
# BRD-K64925568  0.021497  0.022991  0.040036 -0.025479 -0.015981 -0.033822
# BRD-A13133631 -0.096410 -0.032140  0.041751  0.047089  0.085241  0.010350
# BRD-K84658672  0.056069 -0.012038 -0.076591 -0.114969 -0.035062 -0.066394
# BRD-K00911143 -0.018550  0.003930  0.029707 -0.012683  0.117573 -0.012455
#
#                 dz-1011   dz-1012    dz-102   dz-1021  ...    dz-979  \
# ...

# %%
# adjusting the colum names (disease ids)
good_columns = []
for c in similarity.columns:
    good_columns.append(c.replace('-',':'))

# %%
similarity.columns = good_columns

# %%
# filter self concept Ids 
self_df = dz_con.loc[dz_con['type'] == 'self']
self_df
# Out:
#         dz_id   concept  type
# 0      dz:328  C0013264  self
# 5      dz:323  C0007193  self
# 13     dz:322  C0004623  self
# 160    dz:321  C0085786  self
# 170    dz:320  C0011860  self
# ...       ...       ...   ...
# 17459  dz:849  C0014170  self
# 17460  dz:849  C0007103  self
# 17489  dz:651  C0699790  self
# 17507  dz:657  C0553723  self
# 17534  dz:655  C0007099  self
#
# [1665 rows x 3 columns]

# %%
# filter ancestor concept ids 
ancestors_df = dz_con.loc[dz_con['type'] == 'ancestor']
ancestors_df
# Out:
#         dz_id   concept      type
# 1      dz:328  C0026848  ancestor
# 2      dz:328  C0026850  ancestor
# 3      dz:328  C0012634  ancestor
# 4      dz:328  C0026857  ancestor
# 6      dz:323  C0007222  ancestor
# ...       ...       ...       ...
# 17525  dz:656  C0023903  ancestor
# 17526  dz:656  C0345904  ancestor
# 17527  dz:656  C0024620  ancestor
# 17528  dz:656  C0854795  ancestor
# 17535  dz:655  C0012634  ancestor
#
# [6843 rows x 3 columns]

# %%
# concatenate both tables in one
self_anc_df = pd.concat([self_df, ancestors_df])
self_anc_df = self_anc_df.reset_index(drop=True)
self_anc_df = self_anc_df[['dz_id','concept', 'type']]
self_anc_df
# Out:
#        dz_id   concept      type
# 0     dz:328  C0013264      self
# 1     dz:323  C0007193      self
# 2     dz:322  C0004623      self
# 3     dz:321  C0085786      self
# 4     dz:320  C0011860      self
# ...      ...       ...       ...
# 8503  dz:656  C0023903  ancestor
# 8504  dz:656  C0345904  ancestor
# 8505  dz:656  C0024620  ancestor
# 8506  dz:656  C0854795  ancestor
# 8507  dz:655  C0012634  ancestor
#
# [8508 rows x 3 columns]

# %%
concept_unique = []
concept_unique = self_anc_df['concept'].unique()

# %%
## create a roc curve for each disease concept ID with the AUC score.
# create an AUC scores table with the corresponding concept disease ID.

AUC_scores = []
conc_id_list = []
non_match = []
conc_AUC_table = pd.DataFrame ()
fig, (ax1,ax2) = plt.subplots(nrows=2, sharex=True, sharey=True)
plt.ion()

for i in concept_unique:
    self_anc_conc_df = self_anc_df.loc[self_anc_df['concept'] == i]
    self_anc_conc_df['Indicator']= 1
    self_anc_conc_df = pd.pivot_table(self_anc_conc_df, index='concept', columns='dz_id', values='Indicator')
    self_anc_conc_df[self_anc_conc_df.isna()] = 0
    self_anc_conc_df = self_anc_conc_df.astype(int)
    common_db = list(set(brd_conc.columns) & set(self_anc_conc_df.index))
    if len(common_db)>0:
        conc_df_brd_dz = brd_conc[common_db] @ self_anc_conc_df.loc[common_db]
        common_brd = list(set(conc_df_brd_dz.index) & set(similarity.index))
        if len(common_brd)>0:
            common_dz = list(set(conc_df_brd_dz.columns) & set(similarity.columns))
            if len(common_dz)>0:
                conc_ed =  conc_df_brd_dz.loc[common_brd,common_dz]
                sim_df =  similarity.loc[common_brd,common_dz]
                conc_ed[conc_ed>0] = 1
                y_tr = conc_ed.values.reshape((1, -1))[0]
                y_pr = sim_df .values.reshape((1,-1))[0]
                fpr, tpr, thr = roc_curve(y_true=y_tr, y_score=y_pr)
                fig = plt.plot(fpr, tpr)
                plt.xlabel('FPR')
                plt.ylabel('TPR')
                if y_tr.sum()>0:
                    AUC = roc_auc_score(y_true=y_tr, y_score=y_pr)
                    AUC_scores.append(AUC)
                    conc_id_list.append(i)
                    roc_auc_score(y_true=y_tr, y_score=y_pr)
                    title = i + ' ' + ' AUC' + '  ' +  str(AUC)
                    plt.title(title)
#                     plt.savefig('../../../data/results/roc curves 2/' + i + '_roc_curve.pdf')
                    plt.pause(0.1)
                    plt.ioff()  
          
conc_AUC_table['conc_ids'] = conc_id_list
conc_AUC_table['AUC'] = AUC_scores
# Out:
# <ipython-input-11-c765effd43cc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self_anc_conc_df['Indicator']= 1
# <ipython-input-11-c765effd43cc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self_anc_conc_df['Indicator']= 1
# <ipython-input-11-c765effd43cc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
conc_AUC_table
# Out:
#      conc_ids       AUC
# 0    C0013264  0.307077
# 1    C0004623  0.770322
# 2    C0085786  0.467390
# 3    C0011860  0.502078
# 4    C0023418  0.496230
# ..        ...       ...
# 134  C0017612  0.512544
# 135  C0026987  0.001461
# 136  C0007114  0.201389
# 137  C1292778  0.436630
# 138  C0005779  0.971512
#
# [139 rows x 2 columns]

# %%
median=conc_AUC_table['AUC'].median()
mean=conc_AUC_table['AUC'].mean()
mode = conc_AUC_table['AUC'].mode()

# %%
# plot a histogram of the diseases AUC scores
sns.set_theme()
sns.set(style="darkgrid")
hist = sns.distplot(conc_AUC_table["AUC"], color = 'green')
Mean = hist.axvline(mean, color='red', linestyle='-', label="Mean")
Median = hist.axvline(median, color='black', linestyle='-', label="Median")
plt.legend(['KDE','Mean', 'Median'])
plt.title('Self and Ancestor Diseases', fontsize=14)
plt.xlabel('AUC scores', fontsize=11)
plt.ylabel('Density', fontsize=11)
# Out:
# C:\Users\Saba\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')

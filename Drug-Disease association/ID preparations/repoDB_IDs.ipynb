# %%
import pandas as pd
import numpy as np

# %%
# read repoDB dataset
repoDB = pd.read_csv('C:/Users/Saba/Desktop/Tutored research project/DrugRepurposing/data/repoDB.csv', sep=',', header=0, index_col=None)

# %%
repoDB
# Out:
#           drug_name  drug_id  \
# 0         Lepirudin  DB00001
# 1         Cetuximab  DB00002
# 2         Cetuximab  DB00002
# 3         Cetuximab  DB00002
# 4         Cetuximab  DB00002
# ...             ...      ...
# 10557  Temozolomide  DB00853
# 10558     Dasatinib  DB01254
# 10559   Dacarbazine  DB00851
# 10560  Temozolomide  DB00853
# 10561     Dasatinib  DB01254
#
#                                                ind_name    ind_id  \
# 0      Heparin-induced thrombocytopenia with thrombosis  C0272275
# 1                      Squamous cell carcinoma of mouth  C0585362
# 2                       Squamous cell carcinoma of nose  C3163899
# 3                    Squamous cell carcinoma of pharynx  C1319317
# 4                     Laryngeal Squamous Cell Carcinoma  C0280324
# ...                                                 ...       ...
# 10557                                      CNS disorder  C0007682
# 10558                                      CNS disorder  C0007682
# ...

# %%
# repoDB table with concept ID and drugBank ID
repoDB_match = pd.DataFrame()
repoDB_match['concept_id'] = repoDB['ind_id']
repoDB_match['drug_id'] = repoDB['drug_id']
repoDB_match
# Out:
#       concept_id  drug_id
# 0       C0272275  DB00001
# 1       C0585362  DB00002
# 2       C3163899  DB00002
# 3       C1319317  DB00002
# 4       C0280324  DB00002
# ...          ...      ...
# 10557   C0007682  DB00853
# 10558   C0007682  DB01254
# 10559   C0006111  DB00851
# 10560   C0006111  DB00853
# 10561   C0006111  DB01254
#
# [10562 rows x 2 columns]

# %%
repoDB_match.to_csv('../../data/repoDB_match.csv')
